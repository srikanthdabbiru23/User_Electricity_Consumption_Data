# %%
import numpy as np
import pandas as pd
# %matplotlib inline

import seaborn as sns

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
df = pd.read_excel('/Users/shri/Downloads/Interview_Cleaned.xlsx', dtype = {'USAGE': np.float64})
print(df.dtypes)
# Out:
# TYPE                  object
# DATE          datetime64[ns]
# START TIME            object
# END TIME              object
# USAGE                float64
# UNITS                 object
# COST                 float64
# NOTES                 object
# dtype: object

# %%
df.head(10)
# Out:
#              TYPE       DATE START TIME  END TIME  USAGE UNITS  COST NOTES
# 0  Electric usage 2016-11-01   00:00:00  00:14:00   0.07   kWh  0.01   NaN
# 1  Electric usage 2016-11-01   00:15:00  00:29:00   0.05   kWh  0.01   NaN
# 2  Electric usage 2016-11-01   00:30:00  00:44:00   0.06   kWh  0.01   NaN
# 3  Electric usage 2016-11-01   00:45:00  00:59:00   0.05   kWh  0.01   NaN
# 4  Electric usage 2016-11-01   01:00:00  01:14:00   0.03   kWh  0.01   NaN
# 5  Electric usage 2016-11-01   01:15:00  01:29:00   0.03   kWh  0.01   NaN
# 6  Electric usage 2016-11-01   01:30:00  01:44:00   0.03   kWh  0.01   NaN
# 7  Electric usage 2016-11-01   01:45:00  01:59:00   0.06   kWh  0.01   NaN
# 8  Electric usage 2016-11-01   02:00:00  02:14:00   0.04   kWh  0.01   NaN
# 9  Electric usage 2016-11-01   02:15:00  02:29:00   0.03   kWh  0.01   NaN

# %%
df.fillna(0)
# Out:
#                                                     TYPE                 DATE  \
# 0                                         Electric usage  2016-11-01 00:00:00
# 1                                         Electric usage  2016-11-01 00:00:00
# 2                                         Electric usage  2016-11-01 00:00:00
# 3                                         Electric usage  2016-11-01 00:00:00
# 4                                         Electric usage  2016-11-01 00:00:00
# 5                                         Electric usage  2016-11-01 00:00:00
# 6                                         Electric usage  2016-11-01 00:00:00
# 7                                         Electric usage  2016-11-01 00:00:00
# 8                                         Electric usage  2016-11-01 00:00:00
# 9                                         Electric usage  2016-11-01 00:00:00
# 10                                        Electric usage  2016-11-01 00:00:00
# 11                                        Electric usage  2016-11-01 00:00:00
# 12                                        Electric usage  2016-11-01 00:00:00
# 13                                        Electric usage  2016-11-01 00:00:00
# 14                                        Electric usage  2016-11-01 00:00:00
# 15                                        Electric usage  2016-11-01 00:00:00
# 16                                        Electric usage  2016-11-01 00:00:00
# 17                                        Electric usage  2016-11-01 00:00:00
# 18                                        Electric usage  2016-11-01 00:00:00
# 19                                        Electric usage  2016-11-01 00:00:00
# 20                                        Electric usage  2016-11-01 00:00:00
# 21                                        Electric usage  2016-11-01 00:00:00
# 22                                        Electric usage  2016-11-01 00:00:00
# 23                                        Electric usage  2016-11-01 00:00:00
# 24                                        Electric usage  2016-11-01 00:00:00
# 25                                        Electric usage  2016-11-01 00:00:00
# 26                                        Electric usage  2016-11-01 00:00:00
# 27                                        Electric usage  2016-11-01 00:00:00
# 28                                        Electric usage  2016-11-01 00:00:00
# 29                                        Electric usage  2016-11-01 00:00:00
# 24955  Electric usage 2017-07-21   00:30:00  00:44:00   0.03   kWh  0.01
# 24956  Electric usage 2017-07-21   00:45:00  00:59:00   0.02   kWh  0.00
# 24957  Electric usage 2017-07-21   01:00:00  01:14:00   0.02   kWh  0.00
# 24958  Electric usage 2017-07-21   01:15:00  01:29:00   0.02   kWh  0.00
# 24959  Electric usage 2017-07-21   01:30:00  01:44:00   0.02   kWh  0.00
# 24960  Electric usage 2017-07-21   01:45:00  01:59:00   0.02   kWh  0.00
# 24961  Electric usage 2017-07-21   02:00:00  02:14:00   0.02   kWh  0.00
# 24962  Electric usage 2017-07-21   02:15:00  02:29:00   0.03   kWh  0.01
# 24963  Electric usage 2017-07-21   02:30:00  02:44:00   0.03   kWh  0.01
# 29958  Electric usage 2017-09-11   03:30:00  03:44:00   0.02   kWh  0.00
# 29959  Electric usage 2017-09-11   03:45:00  03:59:00   0.03   kWh  0.01
# 29960  Electric usage 2017-09-11   04:00:00  04:14:00   0.03   kWh  0.01
# 30050  Electric usage 2017-09-12   02:30:00  02:44:00   0.03   kWh  0.01
# 30051  Electric usage 2017-09-12   02:45:00  02:59:00   0.04   kWh  0.01
# 30249  Electric usage 2017-09-14   04:15:00  04:29:00   0.40   kWh  0.08
# 30250  Electric usage 2017-09-14   04:30:00  04:44:00   0.40   kWh  0.08
# 30251  Electric usage 2017-09-14   04:45:00  04:59:00   0.40   kWh  0.08
# 30252  Electric usage 2017-09-14   05:00:00  05:14:00   0.40   kWh  0.08
# 30253  Electric usage 2017-09-14   05:15:00  05:29:00   0.40   kWh  0.08
# 30254  Electric usage 2017-09-14   05:30:00  05:44:00   0.40   kWh  0.08
# 30255  Electric usage 2017-09-14   05:45:00  05:59:00   0.40   kWh  0.08
# 30256  Electric usage 2017-09-14   06:00:00  06:14:00   0.40   kWh  0.08
# 30851  Electric usage 2017-09-20   10:45:00  10:59:00   0.06   kWh  0.01
# 30852  Electric usage 2017-09-20   11:00:00  11:14:00   0.04   kWh  0.01
# 30853  Electric usage 2017-09-20   11:15:00  11:29:00   0.02   kWh  0.00
# 30854  Electric usage 2017-09-20   11:30:00  11:44:00   0.01   kWh  0.00
# 30855  Electric usage 2017-09-20   11:45:00  11:59:00   0.01   kWh  0.00
# 30856  Electric usage 2017-09-20   12:00:00  12:14:00   0.01   kWh  0.00
# 30857  Electric usage 2017-09-20   12:15:00  12:29:00   0.01   kWh  0.00
# 30858  Electric usage 2017-09-20   12:30:00  12:44:00   0.02   kWh  0.00
# 30859  Electric usage 2017-09-20   12:45:00  12:59:00   0.02   kWh  0.00
# 30860  Electric usage 2017-09-20   13:00:00  13:14:00   0.01   kWh  0.00
#
#                            NOTES
# 2152   * This data was estimated
# 2153   * This data was estimated
# 12534  * This data was estimated
# 24951  * This data was estimated
# 24952  * This data was estimated
# 24953  * This data was estimated
# 24954  * This data was estimated
# 24955  * This data was estimated
# 24956  * This data was estimated
# 24957  * This data was estimated
# 24958  * This data was estimated
# 24959  * This data was estimated
# 24960  * This data was estimated
# 24961  * This data was estimated
# 24962  * This data was estimated
# 24963  * This data was estimated
# 29958  * This data was estimated
# 29959  * This data was estimated
# 29960  * This data was estimated
# 30050  * This data was estimated
# 30051  * This data was estimated
# 30249  * This data was estimated
# 30250  * This data was estimated
# 30251  * This data was estimated
# 30252  * This data was estimated
# 30253  * This data was estimated
# 30254  * This data was estimated
# 30255  * This data was estimated
# 30256  * This data was estimated
# 30851  * This data was estimated
# 30852  * This data was estimated
# 30853  * This data was estimated
# 30854  * This data was estimated
# 30855  * This data was estimated
# 30856  * This data was estimated
# 30857  * This data was estimated
# 30858  * This data was estimated
# 30859  * This data was estimated
# 30860  * This data was estimated

# %%
df
# Out:
#                                                     TYPE       DATE  \
# 0                                         Electric usage 2016-11-01
# 1                                         Electric usage 2016-11-01
# 2                                         Electric usage 2016-11-01
# 3                                         Electric usage 2016-11-01
# 4                                         Electric usage 2016-11-01
# 5                                         Electric usage 2016-11-01
# 6                                         Electric usage 2016-11-01
# 7                                         Electric usage 2016-11-01
# 8                                         Electric usage 2016-11-01
# 9                                         Electric usage 2016-11-01
# 10                                        Electric usage 2016-11-01
# 11                                        Electric usage 2016-11-01
# 12                                        Electric usage 2016-11-01
# 13                                        Electric usage 2016-11-01
# 14                                        Electric usage 2016-11-01
# 15                                        Electric usage 2016-11-01
# 16                                        Electric usage 2016-11-01
# 17                                        Electric usage 2016-11-01
# 18                                        Electric usage 2016-11-01
# 19                                        Electric usage 2016-11-01
# 20                                        Electric usage 2016-11-01
# 21                                        Electric usage 2016-11-01
# 22                                        Electric usage 2016-11-01
# 23                                        Electric usage 2016-11-01
# 24                                        Electric usage 2016-11-01
# 25                                        Electric usage 2016-11-01
# 26                                        Electric usage 2016-11-01
# 27                                        Electric usage 2016-11-01
# 28                                        Electric usage 2016-11-01
# 29                                        Electric usage 2016-11-01
# ...                                                  ...        ...
# 31835                                     Electric usage 2017-09-30
# 31836                                     Electric usage 2017-09-30
# 31837                                     Electric usage 2017-09-30
# 31838                                     Electric usage 2017-09-30
# 31839                                     Electric usage 2017-09-30
# 31840                                     Electric usage 2017-09-30
# 31841                                     Electric usage 2017-09-30
# 31842                                     Electric usage 2017-09-30
# 31843                                     Electric usage 2017-09-30
# 31844                                     Electric usage 2017-09-30
# 31845                                     Electric usage 2017-09-30
# 31846                                     Electric usage 2017-09-30
# 31847                                     Electric usage 2017-09-30
# 31848                                     Electric usage 2017-09-30
# 31849                                     Electric usage 2017-09-30
# 31850                                     Electric usage 2017-09-30
# 31851                                     Electric usage 2017-09-30
# 31852                                     Electric usage 2017-09-30
# 31853                                     Electric usage 2017-09-30
# 31854                                     Electric usage 2017-09-30
# 31855                                     Electric usage 2017-09-30
# 31856                                     Electric usage 2017-09-30
# 31857                                     Electric usage 2017-09-30
# 31858                                     Electric usage 2017-09-30
# 31859                                     Electric usage 2017-09-30
# 31860                                     Electric usage 2017-09-30
# 31861                                     Electric usage 2017-09-30
# 31862                                     Electric usage 2017-09-30
# 31848   20:00:00  20:14:00   0.14   kWh  0.03   NaN
# 31849   20:15:00  20:29:00   0.13   kWh  0.03   NaN
# 31850   20:30:00  20:44:00   0.12   kWh  0.02   NaN
# 31851   20:45:00  20:59:00   0.12   kWh  0.02   NaN
# 31852   21:00:00  21:14:00   0.10   kWh  0.02   NaN
# 31853   21:15:00  21:29:00   0.09   kWh  0.02   NaN
# 31854   21:30:00  21:44:00   0.10   kWh  0.02   NaN
# 31855   21:45:00  21:59:00   0.12   kWh  0.02   NaN
# 31856   22:00:00  22:14:00   0.12   kWh  0.02   NaN
# 31857   22:15:00  22:29:00   0.12   kWh  0.02   NaN
# 31858   22:30:00  22:44:00   0.10   kWh  0.02   NaN
# 31859   22:45:00  22:59:00   0.10   kWh  0.02   NaN
# 31860   23:00:00  23:14:00   0.11   kWh  0.02   NaN
# 31861   23:15:00  23:29:00   0.10   kWh  0.02   NaN
# 31862   23:30:00  23:44:00   0.08   kWh  0.02   NaN
# 31863   23:45:00  23:59:00   0.04   kWh  0.01   NaN
# 31864        NaN       NaN    NaN   NaN   NaN   NaN
#
# [31865 rows x 8 columns]

# %%
## Seaborn Pairplot, Distplot to understand how the columns relate to each other

# %%
sns.pairplot(df, hue = 'COST')

# %%
sns.distplot(df ['USAGE'].dropna(), kde = False, bins = 30)
# Out:
# /Users/shri/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
## Notice the Logistic Regression Model execution, along with the Classification report

# %%
from sklearn.cross_validation import train_test_split

# %%
X = df.drop(str('USAGE'), axis = 1)

# %%
y = df[str('USAGE')]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-185-d7218c8e69f8> in <module>()
# ----> 1 logmodel.fit(X_train,y_train)
#       2 predictions = logmodel.predict(X_test)
#       3 from sklearn.metrics import classification_report
#       4 print(classification_report(y_test, predictions))
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1214
#    1215         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
# -> 1216                          order="C")
#    1217         check_classification_targets(y)
#    1218         self.classes_ = np.unique(y)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# TypeError: float() argument must be a string or a number, not 'datetime.time'
